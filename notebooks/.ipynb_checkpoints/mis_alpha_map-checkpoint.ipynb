# %%
# Compute and get alpha map
import os
os.environ["OPENCV_IO_ENABLE_OPENEXR"]="1"
import cv2
import numpy as np
import xml.dom.minidom as md

from skimage.metrics import structural_similarity as ssim
from skimage.metrics import normalized_root_mse as nrmse
from skimage.metrics import mean_squared_error as mse
from PIL import Image

output_folder = 'images'
ref_output_folder = 'images/references'
mitsuba_binary = './../build/mitsuba'
os.makedirs(ref_output_folder, exist_ok=True)

# %%
def convert_img(im):
    im_gamma_correct = np.clip(np.power(im, 0.45), 0, 1)
    im_fixed = Image.fromarray(np.uint8(im_gamma_correct*255))
    
    return np.array(im_fixed)

def update_mis_scene(scene_path, mis_method):
    file = md.parse(scene_path) 
    scene = file.getElementsByTagName("scene")
    defaults = scene[0].getElementsByTagName("default")

    mis_param = [ param for param in defaults if param.attributes['name'].value == 'mis' ][0]
    mis_param.setAttribute('value', mis_method)

    with open(scene_path, "w") as xml_file:
        file.writexml(xml_file)
        
def update_spp_scene(scene_path, spp):
    file = md.parse(scene_path) 
    scene = file.getElementsByTagName("scene")
    defaults = scene[0].getElementsByTagName("default")

    spp_param = [ param for param in defaults if param.attributes['name'].value == 'spp' ][0]
    spp_param.setAttribute('value', spp)

    with open(scene_path, "w") as xml_file:
        file.writexml(xml_file)
        
def read_alpha_map(alpha_map_path):
    
    alpha_arr = []
    with open(alpha_map_path, 'r') as f:
        for line in f.readlines():
            pixel_line = line.split(';')
            pixels_channels = [ list(map(float, pixel.split(','))) for pixel in pixel_line ]
            alpha_arr.append(pixels_channels)
    return np.array(alpha_arr)
        
def compute_methods(ref, scene_file, methods):
    
    computed_images = {}
    for mis_method in methods:
        
        _, scene_name = os.path.split(scene_file)
        scene_name = scene_name.replace('.xml', '')

        output_image_path = f"{output_folder}/{scene_name}_{mis_method}.exr"

        # update scene params
        update_mis_scene(scene_file, mis_method)
    
        # render and load image
        os.system(f'{mitsuba_binary} -t 8 -o {output_image_path} {scene_file}')
        
        image = np.array(cv2.imread(output_image_path))
        image = convert_img(image)
        
        # read alpha map now
        alpha_map_path = output_image_path.replace('.exr', '.map')
        image_map = read_alpha_map(alpha_map_path)

        if mis_method not in computed_images:
            # tuple with image and alpha map
            computed_images[mis_method] = (image, image_map)
            
        print(f'{mis_method}: [MSE: {mse(ref, image)}, SSIM: {ssim(ref, image, channel_axis=2)}]')

# %%
alpha_map = read_alpha_map('images/scene_tsallis.map')
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10, 10))
fig.add_subplot(1,1,1).imshow(alpha_map[:,:,0], cmap='RdBu', clim=(0, 1)) 
plt.axis('off'); plt.title('Power')
#fig.add_subplot(1,2,2).imshow(tsallis); plt.axis('off'); plt.title('Tsallis')
#print(f'[NRMSE: {nrmse(ref, tsallis)}, SSIM: {ssim(ref, tsallis, channel_axis=2, data_range=1)}]')
# Out:
# Text(0.5, 1.0, 'Power')

# %%
methods = ["balance", "power", "tsallis", "linear1", "linear2", "linear3"]

# %%
ref_image_path = os.path.join(ref_output_folder, 'veach_power.exr')
scene_file = "scenes/veach-mis/scene.xml"
update_spp_scene(scene_file, '1000')
if not os.path.exists(ref_image_path):
    os.system(f'{mitsuba_binary} -t 8 -o {ref_image_path} {scene_file}')

# %%
image = np.array(cv2.imread(ref_image_path))
ref = convert_img(image)
# reset spp
update_spp_scene(scene_file, "100")
compute_methods(ref, "scenes/veach-mis/scene_no_background.xml", methods)
# Out:
# 2023-03-15 15:50:23 INFO  main  [mitsuba.cpp:335] Mitsuba version 3.2.1 (develop[ac088c3b], Linux, 64bit, 8 threads, 8-wide SIMD)
# 2023-03-15 15:50:23 INFO  main  [mitsuba.cpp:336] Copyright 2022, Realistic Graphics Lab, EPFL
# 2023-03-15 15:50:23 INFO  main  [mitsuba.cpp:337] Enabled processor features: avx2 avx fma f16c sse4.2 x86_64
# 2023-03-15 15:50:23 INFO  main  [xml.cpp:1433] Loading XML file "scenes/veach-mis/scene.xml" with variant "scalar_rgb"..
# 2023-03-15 15:50:24 INFO  main  [Scene] Embree ready. (took 0ms)
# 2023-03-15 15:50:24 INFO  main  [xml.cpp:1450] Done loading XML file "scenes/veach-mis/scene.xml" (took 874ms).
# 2023-03-15 15:50:24 INFO  main  [SamplingIntegrator] Starting render job (1280x720, 100 samples, 8 threads)
# Rendering [=============================================] (15.8s, ETA: 0ms)
# 2023-03-15 15:50:40 INFO  main  [SamplingIntegrator] Rendering finished. (took 15.843s)
# 2023-03-15 15:50:40 INFO  main  [HDRFilm] ✔  Developing "images/scene_balance.exr" ..
# AlphaMap saved into: images/scene_balance.map
# balance: [MSE: 74.578369140625, SSIM: 0.9933075325884534]
# 2023-03-15 15:50:41 INFO  main  [mitsuba.cpp:335] Mitsuba version 3.2.1 (develop[ac088c3b], Linux, 64bit, 8 threads, 8-wide SIMD)
# 2023-03-15 15:50:41 INFO  main  [mitsuba.cpp:336] Copyright 2022, Realistic Graphics Lab, EPFL
# 2023-03-15 15:50:41 INFO  main  [mitsuba.cpp:337] Enabled processor features: avx2 avx fma f16c sse4.2 x86_64
# 2023-03-15 15:50:41 INFO  main  [xml.cpp:1433] Loading XML file "scenes/veach-mis/scene.xml" with variant "scalar_rgb"..
# 2023-03-15 15:50:42 INFO  main  [Scene] Embree ready. (took 0ms)
# 2023-03-15 15:50:42 INFO  main  [xml.cpp:1450] Done loading XML file "scenes/veach-mis/scene.xml" (took 812ms).
# 2023-03-15 15:50:42 INFO  main  [SamplingIntegrator] Starting render job (1280x720, 100 samples, 8 threads)
# Rendering [=============================================] (15.6s, ETA: 0ms)
# 2023-03-15 15:50:57 INFO  main  [SamplingIntegrator] Rendering finished. (took 15.552s)
# 2023-03-15 15:50:57 INFO  main  [HDRFilm] ✔  Developing "images/scene_power.exr" ..
# AlphaMap saved into: images/scene_power.map
# power: [MSE: 76.50691731770833, SSIM: 0.9931945780666274]
# 2023-03-15 15:50:59 INFO  main  [mitsuba.cpp:335] Mitsuba version 3.2.1 (develop[ac088c3b], Linux, 64bit, 8 threads, 8-wide SIMD)
# 2023-03-15 15:50:59 INFO  main  [mitsuba.cpp:336] Copyright 2022, Realistic Graphics Lab, EPFL
# 2023-03-15 15:50:59 INFO  main  [mitsuba.cpp:337] Enabled processor features: avx2 avx fma f16c sse4.2 x86_64
# 2023-03-15 15:50:59 INFO  main  [xml.cpp:1433] Loading XML file "scenes/veach-mis/scene.xml" with variant "scalar_rgb"..
# 2023-03-15 15:51:00 INFO  main  [Scene] Embree ready. (took 0ms)
# 2023-03-15 15:51:00 INFO  main  [xml.cpp:1450] Done loading XML file "scenes/veach-mis/scene.xml" (took 826ms).
# 2023-03-15 15:51:00 INFO  main  [SamplingIntegrator] Starting render job (1280x720, 100 samples, 8 threads)
# Rendering [=============================================] (16.4s, ETA: 0ms)
# 2023-03-15 15:51:16 INFO  main  [SamplingIntegrator] Rendering finished. (took 16.36s)
# 2023-03-15 15:51:16 INFO  main  [HDRFilm] ✔  Developing "images/scene_tsallis.exr" ..
# AlphaMap saved into: images/scene_tsallis.map
# tsallis: [MSE: 114.32527669270833, SSIM: 0.9873823475718125]
# 2023-03-15 15:51:18 INFO  main  [mitsuba.cpp:335] Mitsuba version 3.2.1 (develop[ac088c3b], Linux, 64bit, 8 threads, 8-wide SIMD)
# 2023-03-15 15:51:18 INFO  main  [mitsuba.cpp:336] Copyright 2022, Realistic Graphics Lab, EPFL
# 2023-03-15 15:51:18 INFO  main  [mitsuba.cpp:337] Enabled processor features: avx2 avx fma f16c sse4.2 x86_64
# 2023-03-15 15:51:18 INFO  main  [xml.cpp:1433] Loading XML file "scenes/veach-mis/scene.xml" with variant "scalar_rgb"..
# 2023-03-15 15:51:18 INFO  main  [Scene] Embree ready. (took 0ms)
# 2023-03-15 15:51:18 INFO  main  [xml.cpp:1450] Done loading XML file "scenes/veach-mis/scene.xml" (took 803ms).
# 2023-03-15 15:51:18 INFO  main  [SamplingIntegrator] Starting render job (1280x720, 100 samples, 8 threads)
# Rendering [=============================================] (18s, ETA: 0ms)
# 2023-03-15 15:51:36 INFO  main  [SamplingIntegrator] Rendering finished. (took 17.986s)
# 2023-03-15 15:51:36 INFO  main  [HDRFilm] ✔  Developing "images/scene_linear1.exr" ..
# AlphaMap saved into: images/scene_linear1.map
# linear1: [MSE: 160.35172526041666, SSIM: 0.9759069187751948]
# 2023-03-15 15:51:38 INFO  main  [mitsuba.cpp:335] Mitsuba version 3.2.1 (develop[ac088c3b], Linux, 64bit, 8 threads, 8-wide SIMD)
# 2023-03-15 15:51:38 INFO  main  [mitsuba.cpp:336] Copyright 2022, Realistic Graphics Lab, EPFL
# 2023-03-15 15:51:38 INFO  main  [mitsuba.cpp:337] Enabled processor features: avx2 avx fma f16c sse4.2 x86_64
# 2023-03-15 15:51:38 INFO  main  [xml.cpp:1433] Loading XML file "scenes/veach-mis/scene.xml" with variant "scalar_rgb"..
# 2023-03-15 15:51:39 INFO  main  [Scene] Embree ready. (took 0ms)
# 2023-03-15 15:51:39 INFO  main  [xml.cpp:1450] Done loading XML file "scenes/veach-mis/scene.xml" (took 799ms).
# 2023-03-15 15:51:39 INFO  main  [SamplingIntegrator] Starting render job (1280x720, 100 samples, 8 threads)
# Rendering [=============================================] (17.8s, ETA: 0ms)
# 2023-03-15 15:51:56 INFO  main  [SamplingIntegrator] Rendering finished. (took 17.798s)
# 2023-03-15 15:51:56 INFO  main  [HDRFilm] ✔  Developing "images/scene_linear2.exr" ..
# AlphaMap saved into: images/scene_linear2.map
# linear2: [MSE: 160.35172526041666, SSIM: 0.9759069187751948]
# 2023-03-15 15:51:58 INFO  main  [mitsuba.cpp:335] Mitsuba version 3.2.1 (develop[ac088c3b], Linux, 64bit, 8 threads, 8-wide SIMD)
# 2023-03-15 15:51:58 INFO  main  [mitsuba.cpp:336] Copyright 2022, Realistic Graphics Lab, EPFL
# 2023-03-15 15:51:58 INFO  main  [mitsuba.cpp:337] Enabled processor features: avx2 avx fma f16c sse4.2 x86_64
# 2023-03-15 15:51:58 INFO  main  [xml.cpp:1433] Loading XML file "scenes/veach-mis/scene.xml" with variant "scalar_rgb"..
# 2023-03-15 15:51:59 INFO  main  [Scene] Embree ready. (took 0ms)
# 2023-03-15 15:51:59 INFO  main  [xml.cpp:1450] Done loading XML file "scenes/veach-mis/scene.xml" (took 837ms).
# 2023-03-15 15:51:59 INFO  main  [SamplingIntegrator] Starting render job (1280x720, 100 samples, 8 threads)
# Rendering [=============================================] (17.8s, ETA: 0ms)
# 2023-03-15 15:52:17 INFO  main  [SamplingIntegrator] Rendering finished. (took 17.845s)
# 2023-03-15 15:52:17 INFO  main  [HDRFilm] ✔  Developing "images/scene_linear3.exr" ..
# AlphaMap saved into: images/scene_linear3.map
# linear3: [MSE: 160.35172526041666, SSIM: 0.9759069187751948]
